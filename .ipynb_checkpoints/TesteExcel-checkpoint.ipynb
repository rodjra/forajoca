# %%
import pandas as pd

# %% [markdown]
# #  ESTOQUE

# %%
pd.read_excel('Analise Lotes Estoque.xlsx')
# Out:
#                                   Arquivos       DATA  QUADRA   LOTE    Q-L  \
# 0     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        2     1    2-1
# 1     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        2    16   2-16
# 2     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        3     9    3-9
# 3     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        3    24   3-24
# 4     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        4     1    4-1
# ...                                    ...        ...      ...   ...    ...
# 9217   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       22     9   22-9
# 9218   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       22    10  22-10
# 9219   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       22    11  22-11
# 9220   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       22    12  22-12
# 9221   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       29    25  29-25
#
# ...

# %%
df1=pd.read_excel('Analise Lotes Estoque.xlsx')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9222 entries, 0 to 9221
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Arquivos  9222 non-null   object
#  1   DATA      9222 non-null   datetime64[ns]
#  2   QUADRA    9222 non-null   int64
#  3   LOTE      9222 non-null   int64
#  4   Q-L       9222 non-null   object
#  5   ÁREA      8955 non-null   object
#  6   TABELA    209 non-null    object
#  7   GABARITO  7858 non-null   object
#  8   POSIÇÃO   1005 non-null   object
#  9   REAJUSTE  121 non-null    object
#  10  MOEDA     235 non-null    object
#  11  DT VENDA  91 non-null     object
#  12  C         3459 non-null   object
#  13  M         3431 non-null   object
#  14  SITUACAO  9222 non-null   object
#  15  CUSTO     8847 non-null   object
#  16  Column16  2704 non-null   object
#  17  Column17  1553 non-null   object
#  18  Column18  0 non-null      float64
# ...

# %%
df1.dropna(subset=['Column18'])
df1
# Out:
#                                   Arquivos       DATA  QUADRA   LOTE    Q-L  \
# 0     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        2     1    2-1
# 1     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        2    16   2-16
# 2     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        3     9    3-9
# 3     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        3    24   3-24
# 4     Relaçao de Lotes  DEZEMBRO 2001.xlsx 2001-12-01        4     1    4-1
# ...                                    ...        ...      ...   ...    ...
# 9217   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       22     9   22-9
# 9218   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       22    10  22-10
# 9219   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       22    11  22-11
# 9220   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       22    12  22-12
# 9221   Relação de Lotes SETEMBRO 2019.xlsx 2019-09-01       29    25  29-25
#
# ...

# %%
df1.groupby(['DATA','Q-L','SITUACAO']).sum()
# Out:
#                             QUADRA   LOTE  Column18
# DATA       Q-L   SITUACAO
# 2001-12-01 1-1   RESERVADO        1     1       0.0
#            1-2   RESERVADO        1     2       0.0
#            1-3   RESERVADO        1     3       0.0
#            1-4   RESERVADO        1     4       0.0
#            1-5   RESERVADO        1     5       0.0
# ...                             ...   ...       ...
# 2019-12-01 56-36 RESERVADO       56    36       0.0
#            57-17 RESERVADO       57    17       0.0
#            58-3  ESTOQUE         58     3       0.0
#            61-17 ESTOQUE         61    17       0.0
#            62-33 ESTOQUE         62    33       0.0
#
# [9117 rows x 3 columns]

# %% [markdown]
# #  OCORRÊNCIAS

# %%
pd.read_excel('Analise Lotes Ocorrencias.xlsx')
# Out:
#        QUADRA  LOTE    Q-L DIVISÃO 2005  \
# 0          41    24  41-24    REDENTORA
# 1           7     2    7-2           NI
# 2          29    24  29-24    REDENTORA
# 3           8    19   8-19    REDENTORA
# 4           8    12   8-12       ARROYO
# ...       ...   ...    ...          ...
# 14686      32     4   32-4       ARROYO
# 14687      59     5   59-5       ARROYO
# 14688      60    38  60-38       ARROYO
# 14689      36    31  36-31       ARROYO
# 14690      59     5   59-5       ARROYO
#
#                                      COMPRADOR       date       DATA  \
# 0       RITA DE CASSIA OLIVEIRA MARTINS JACOVA 2000-01-15 2000-01-01
# 1                     JESUS ANTONIO DE FREITAS 2000-01-08 2000-01-01
# 2      IGREJA EVANG. PENTEC. TENDA DA SALVAÇ/  2000-01-20 2000-01-01
# 3         ADELAIDE DAS GRAÇAS NUNES DOS SANTOS 2000-01-25 2000-01-01
# 4         REGINALDO APARECIDO NUNES DOS SANTOS 2000-03-21 2000-03-01
# ...

# %%
df2=pd.read_excel('Analise Lotes Ocorrencias.xlsx')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14691 entries, 0 to 14690
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   QUADRA           14691 non-null  int64
#  1   LOTE             14691 non-null  int64
#  2   Q-L              14691 non-null  object
#  3   DIVISÃO 2005     14691 non-null  object
#  4   COMPRADOR        14251 non-null  object
#  5   date             14691 non-null  datetime64[ns]
#  6   DATA             14691 non-null  datetime64[ns]
#  7   HISTORICO        12428 non-null  object
#  8   VALOR            1398 non-null   object
#  9   OCORRENCIA       14691 non-null  object
#  10  VALOR DEVOLVIDO  177 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
df2.groupby(['DATA','Q-L','OCORRENCIA']).sum()
# Out:
#                              QUADRA  LOTE
# DATA       Q-L   OCORRENCIA
# 2000-01-01 10-14 VENDIDOS        10    14
#            10-15 VENDIDOS        10    15
#            10-22 VENDIDOS        10    22
#            10-26 VENDIDOS        10    26
#            10-3  VENDIDOS        10     3
# ...                             ...   ...
# 2020-04-01 11-3  DIVERSOS        11     3
# 2020-06-01 18-25 VENDIDOS        18    25
# 2020-07-01 50-6  DIVERSOS        50     6
#            62-33 VENDIDOS        62    33
# 2020-09-01 60-31 ADITADOS        60    31
#
# [10255 rows x 2 columns]

# %% [markdown]
# #  RELAÇÕES

# %%
pd.read_excel('Analise Lotes Relacoes.xlsx')
# Out:
#            Nome da Origem                                    Arquivos  \
# 0      Relações 2007.xlsx               Relação de Recibos ABRIL 2007
# 1      Relações 2007.xlsx               Relação de Recibos ABRIL 2007
# 2      Relações 2007.xlsx               Relação de Recibos ABRIL 2007
# 3      Relações 2007.xlsx                Relação de Recibos MAIO 2007
# 4      Relações 2007.xlsx                Relação de Recibos MAIO 2007
# ...                   ...                                         ...
# 55503  Relações 2014.xlsx             Relação de Recibos OUTUBRO 2014
# 55504  Relações 2014.xlsx            Relação de Recibos NOVEMBRO 2014
# 55505  Relações 2014.xlsx            Relação de Recibos DEZEMBRO 2014
# 55506  Relações 2017.xlsx  Relação de Baixas - parcelas DEZEMBRO 2017
# 55507  Relações 2018.xlsx  Relação de Baixas -Parcelas FEVEREIRO 2018
#
#                 Coluna1       DATA  Quadra  Lote   Q-L "DIVISÂO DE 2005"  \
# ...

# %%
df3=pd.read_excel('Analise Lotes Relacoes.xlsx')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55508 entries, 0 to 55507
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Nome da Origem     55508 non-null  object
#  1   Arquivos           55508 non-null  object
#  2   Coluna1            55508 non-null  object
#  3   DATA               55508 non-null  datetime64[ns]
#  4   Quadra             55506 non-null  float64
#  5   Lote               55506 non-null  float64
#  6   Q-L                55508 non-null  object
#  7   "DIVISÂO DE 2005"  55506 non-null  object
#  8   Parcela            55507 non-null  object
#  9   Comprador          47726 non-null  object
#  10  Vcto               55385 non-null  datetime64[ns]
#  11  Pagto              53305 non-null  datetime64[ns]
#  12  Contab             52118 non-null  datetime64[ns]
#  13  Valor              52780 non-null  object
#  14  Outros             53147 non-null  object
# ...

# %%
df3.groupby(['DATA','Q-L','Parcela']).sum()
# Out:
#                           Quadra  Lote
# DATA       Q-L   Parcela
# 2000-05-01 10-22 003/012    10.0  22.0
#            10-25 004/012    10.0  25.0
#            10-26 002/012    10.0  26.0
#            10-3  003/012    10.0   3.0
#            12-1  003/012    12.0   1.0
# ...                          ...   ...
# 2020-08-01 57-20 1/32       57.0  20.0
#            6-12  1/1         6.0  12.0
#                  1/8         6.0  12.0
#            60-26 95/100     60.0  26.0
#            62-21 5/27       62.0  21.0
#
# [53905 rows x 2 columns]
